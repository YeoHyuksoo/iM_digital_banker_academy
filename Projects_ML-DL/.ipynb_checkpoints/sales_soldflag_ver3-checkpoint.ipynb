# %%
import pandas as pd

df = pd.read_csv("Sales.csv")
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# 1         39          0.00        15.54
# 2         34         30.19        27.97
# 3         20        133.93        83.15
# 4         28          4.00        23.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198917 entries, 0 to 198916
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order             198917 non-null  int64
#  1   File_Type         198917 non-null  object
#  2   SKU_number        198917 non-null  int64
#  3   SoldFlag          75996 non-null   float64
#  4   SoldCount         75996 non-null   float64
#  5   MarketingType     198917 non-null  object
#  6   ReleaseNumber     198917 non-null  int64
#  7   New_Release_Flag  198917 non-null  int64
#  8   StrengthFactor    198917 non-null  float64
#  9   PriceReg          198917 non-null  float64
#  10  ReleaseYear       198917 non-null  int64
#  11  ItemCount         198917 non-null  int64
#  12  LowUserPrice      198917 non-null  float64
#  13  LowNetPrice       198917 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 21.2+ MB

# %%
print(df["SoldFlag"].value_counts() / len(df["SoldFlag"]))
# Out:
# 0.0    0.316715
# 1.0    0.065334
# Name: SoldFlag, dtype: float64

# %%
print(df["File_Type"].value_counts() / len(df["File_Type"]))
# Out:
# Active        0.617951
# Historical    0.382049
# Name: File_Type, dtype: float64

# %%
# 재고 가치
df = df[df["PriceReg"] > 0]
df["stockvalue"] = df["ItemCount"] * df["LowNetPrice"]

# %%
# 재고 소진 추정 기간
df.loc["MOC"] = df.ItemCount.sum() / (df.SoldCount.sum()/6)

# %%
# 재고 보관 기간
df["stockage"] = 2024 - df["ReleaseYear"]

# %%
# 판매 할인 비율
import numpy as np

df['discount'] = np.round((df['PriceReg'] - df['LowNetPrice']) / df['PriceReg'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 196369 entries, 0 to MOC
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order             196369 non-null  float64
#  1   File_Type         196369 non-null  object
#  2   SKU_number        196369 non-null  float64
#  3   SoldFlag          74602 non-null   float64
#  4   SoldCount         74602 non-null   float64
#  5   MarketingType     196369 non-null  object
#  6   ReleaseNumber     196369 non-null  float64
#  7   New_Release_Flag  196369 non-null  float64
#  8   StrengthFactor    196369 non-null  float64
#  9   PriceReg          196369 non-null  float64
#  10  ReleaseYear       196369 non-null  float64
#  11  ItemCount         196369 non-null  float64
#  12  LowUserPrice      196369 non-null  float64
#  13  LowNetPrice       196369 non-null  float64
#  14  stockvalue        196369 non-null  float64
#  15  stockage          196369 non-null  float64
#  16  discount          196369 non-null  float64
# dtypes: float64(15), object(2)
# memory usage: 27.0+ MB

# %%
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0    2.0  Historical   1737127.0       0.0        0.0             D
# 1    3.0  Historical   3255963.0       0.0        0.0             D
# 2    4.0  Historical    612701.0       0.0        0.0             D
# 3    6.0  Historical    115883.0       1.0        1.0             D
# 4    7.0  Historical    863939.0       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0           15.0               1.0        682743.0     44.99       2015.0
# 1            7.0               1.0       1016014.0     24.81       2005.0
# 2            0.0               0.0        340464.0     46.00       2013.0
# 3            4.0               1.0        334011.0    100.00       2006.0
# 4            2.0               1.0       1287938.0    121.95       2010.0
#
#    ItemCount  LowUserPrice  LowNetPrice  stockvalue  stockage  discount
# 0        8.0         28.97        31.84      254.72       9.0       0.0
# 1       39.0          0.00        15.54      606.06      19.0       0.0
# 2       34.0         30.19        27.97      950.98      11.0       0.0
# 3       20.0        133.93        83.15     1663.00      18.0       0.0
# 4       28.0          4.00        23.99      671.72      14.0       1.0

# %%
df = df[df["File_Type"] == "Historical"]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for column in df.select_dtypes(include=['object']).columns:
    df[column] = le.fit_transform(df[column])

df.head()
# Out:
#    Order  File_Type  SKU_number  SoldFlag  SoldCount  MarketingType  \
# 0    2.0          0   1737127.0       0.0        0.0              0
# 1    3.0          0   3255963.0       0.0        0.0              0
# 2    4.0          0    612701.0       0.0        0.0              0
# 3    6.0          0    115883.0       1.0        1.0              0
# 4    7.0          0    863939.0       1.0        1.0              0
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0           15.0               1.0        682743.0     44.99       2015.0
# 1            7.0               1.0       1016014.0     24.81       2005.0
# 2            0.0               0.0        340464.0     46.00       2013.0
# 3            4.0               1.0        334011.0    100.00       2006.0
# 4            2.0               1.0       1287938.0    121.95       2010.0
#
#    ItemCount  LowUserPrice  LowNetPrice  stockvalue  stockage  discount
# 0        8.0         28.97        31.84      254.72       9.0       0.0
# 1       39.0          0.00        15.54      606.06      19.0       0.0
# 2       34.0         30.19        27.97      950.98      11.0       0.0
# 3       20.0        133.93        83.15     1663.00      18.0       0.0
# 4       28.0          4.00        23.99      671.72      14.0       1.0

# %%
df = df[df.SoldFlag.notnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74601 entries, 0 to 75995
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order             74601 non-null  float64
#  1   File_Type         74601 non-null  int64
#  2   SKU_number        74601 non-null  float64
#  3   SoldFlag          74601 non-null  float64
#  4   SoldCount         74601 non-null  float64
#  5   MarketingType     74601 non-null  int64
#  6   ReleaseNumber     74601 non-null  float64
#  7   New_Release_Flag  74601 non-null  float64
#  8   StrengthFactor    74601 non-null  float64
#  9   PriceReg          74601 non-null  float64
#  10  ReleaseYear       74601 non-null  float64
#  11  ItemCount         74601 non-null  float64
#  12  LowUserPrice      74601 non-null  float64
#  13  LowNetPrice       74601 non-null  float64
#  14  stockvalue        74601 non-null  float64
#  15  stockage          74601 non-null  float64
#  16  discount          74601 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 10.2+ MB

# %%
print(df["SoldFlag"].value_counts() / len(df["SoldFlag"]))
# Out:
# 0.0    0.828917
# 1.0    0.171083
# Name: SoldFlag, dtype: float64

# %%
X = df.drop(columns=["SoldFlag","SoldCount","Order","SKU_number","File_Type",
                    "ReleaseYear"])
y = df["SoldFlag"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (52220, 13)
# (22381, 13)
# (52220,)
# (22381,)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8273169875871749
#
# confusion matrix:
# [[18268   622]
#  [ 3315   594]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.97      0.90     18890
#          1.0       0.49      0.15      0.23      3909
#
#     accuracy                           0.83     22799
#    macro avg       0.67      0.56      0.57     22799
# weighted avg       0.79      0.83      0.79     22799

# %%
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

print(feature_importance)
# Out:
#             feature  importance
# 4    StrengthFactor    0.178511
# 7         ItemCount    0.164749
# 8      LowUserPrice    0.151725
# 5          PriceReg    0.150793
# 9       LowNetPrice    0.148927
# 6       ReleaseYear    0.088428
# 2     ReleaseNumber    0.069836
# 1     MarketingType    0.040047
# 3  New_Release_Flag    0.006984
# 0         File_Type    0.000000

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier

model = XGBClassifier(n_estimators=300, subsample=0.9, max_depth=4, learning_rate=0.1, gamma=0.5,
                      colsample_bytree=1.0, importance_type='cover', reg_lambda = 1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type='cover',
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8356068248607396
#
# confusion matrix:
# [[18487   403]
#  [ 3345   564]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.98      0.91     18890
#          1.0       0.58      0.14      0.23      3909
#
#     accuracy                           0.84     22799
#    macro avg       0.72      0.56      0.57     22799
# weighted avg       0.80      0.84      0.79     22799

# %%
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

print(feature_importance)
# Out:
#             feature  importance
# 1     MarketingType    0.163442
# 6       ReleaseYear    0.147476
# 2     ReleaseNumber    0.135237
# 7         ItemCount    0.118802
# 4    StrengthFactor    0.117417
# 8      LowUserPrice    0.109803
# 9       LowNetPrice    0.108185
# 5          PriceReg    0.099638
# 0         File_Type    0.000000
# 3  New_Release_Flag    0.000000

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=10)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8324471650060319
#
# confusion matrix:
# [[18239   307]
#  [ 3443   392]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.98      0.91     18546
#          1.0       0.56      0.10      0.17      3835
#
#     accuracy                           0.83     22381
#    macro avg       0.70      0.54      0.54     22381
# weighted avg       0.79      0.83      0.78     22381

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=100000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8342790760019659
#
# confusion matrix:
# [[18242   321]
#  [ 3388   430]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.98      0.91     18563
#          1.0       0.57      0.11      0.19      3818
#
#     accuracy                           0.83     22381
#    macro avg       0.71      0.55      0.55     22381
# weighted avg       0.80      0.83      0.78     22381

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train = pd.DataFrame(X_train, columns = X.columns)

# %%
import statsmodels.api as sm

logreg = sm.Logit(y_train, sm.add_constant(X_train)).fit()
print(logreg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.398264
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               SoldFlag   No. Observations:                52220
# Model:                          Logit   Df Residuals:                    52208
# Method:                           MLE   Df Model:                           11
# Date:                Tue, 10 Dec 2024   Pseudo R-squ.:                  0.1282
# Time:                        17:02:31   Log-Likelihood:                -20797.
# converged:                       True   LL-Null:                       -23855.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.9403      0.063    -14.819      0.000      -1.065      -0.816
# MarketingType       -1.2047      0.027    -44.493      0.000      -1.258      -1.152
# ReleaseNumber        0.0210      0.003      6.202      0.000       0.014       0.028
# New_Release_Flag    -0.2228      0.035     -6.403      0.000      -0.291      -0.155
# StrengthFactor   -3.605e-07   1.54e-08    -23.418      0.000   -3.91e-07    -3.3e-07
# PriceReg             0.0007      0.000      3.560      0.000       0.000       0.001
# ItemCount            0.0043      0.000      9.812      0.000       0.003       0.005
# LowUserPrice         0.0003      0.000      3.045      0.002       0.000       0.001
# LowNetPrice         -0.0055      0.001     -9.231      0.000      -0.007      -0.004
# stockvalue           0.0002   1.29e-05     14.575      0.000       0.000       0.000
# stockage            -0.0058      0.003     -2.312      0.021      -0.011      -0.001
# discount             0.0342      0.026      1.334      0.182      -0.016       0.084
# ====================================================================================

# %%
import numpy as np

odds = np.exp(logreg.params)

for i in range(1, len(odds)):
    print(f'변수 {X_train.columns[i-1]}의 logit : {logreg.params[i] : .3f}')
    print(f'변수 {X_train.columns[i-1]}가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이{logreg.params[i] : .3f}배 증가한다.')
    print(f'변수 {X_train.columns[i-1]}의 odds ratio : {odds[i] : .3f}')
    print(f'변수 {X_train.columns[i-1]}가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다{odds[i] : .3f}배 증가한다.\n')
# Out:
# 변수 MarketingType의 logit : -1.205
# 변수 MarketingType가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이-1.205배 증가한다.
# 변수 MarketingType의 odds ratio :  0.300
# 변수 MarketingType가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 0.300배 증가한다.
#
# 변수 ReleaseNumber의 logit :  0.021
# 변수 ReleaseNumber가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이 0.021배 증가한다.
# 변수 ReleaseNumber의 odds ratio :  1.021
# 변수 ReleaseNumber가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.021배 증가한다.
#
# 변수 New_Release_Flag의 logit : -0.223
# 변수 New_Release_Flag가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이-0.223배 증가한다.
# 변수 New_Release_Flag의 odds ratio :  0.800
# 변수 New_Release_Flag가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 0.800배 증가한다.
#
# 변수 StrengthFactor의 logit : -0.000
# 변수 StrengthFactor가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이-0.000배 증가한다.
# 변수 StrengthFactor의 odds ratio :  1.000
# 변수 StrengthFactor가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.000배 증가한다.
#
# 변수 PriceReg의 logit :  0.001
# 변수 PriceReg가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이 0.001배 증가한다.
# 변수 PriceReg의 odds ratio :  1.001
# 변수 PriceReg가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.001배 증가한다.
#
# 변수 ItemCount의 logit :  0.004
# 변수 ItemCount가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이 0.004배 증가한다.
# 변수 ItemCount의 odds ratio :  1.004
# 변수 ItemCount가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.004배 증가한다.
#
# 변수 LowUserPrice의 logit :  0.000
# 변수 LowUserPrice가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이 0.000배 증가한다.
# 변수 LowUserPrice의 odds ratio :  1.000
# 변수 LowUserPrice가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.000배 증가한다.
#
# 변수 LowNetPrice의 logit : -0.006
# 변수 LowNetPrice가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이-0.006배 증가한다.
# 변수 LowNetPrice의 odds ratio :  0.995
# 변수 LowNetPrice가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 0.995배 증가한다.
#
# 변수 stockvalue의 logit :  0.000
# 변수 stockvalue가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이 0.000배 증가한다.
# 변수 stockvalue의 odds ratio :  1.000
# 변수 stockvalue가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.000배 증가한다.
#
# 변수 stockage의 logit : -0.006
# 변수 stockage가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이-0.006배 증가한다.
# 변수 stockage의 odds ratio :  0.994
# 변수 stockage가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 0.994배 증가한다.
#
# 변수 discount의 logit :  0.034
# 변수 discount가 1단위 증가할 때, 악성재고일 로짓(odds ratio에 자연로그를 취한 값)이 0.034배 증가한다.
# 변수 discount의 odds ratio :  1.035
# 변수 discount가 1단위 증가할 때, 악성재고일 확률(종속변수가 1일 확률)이 그렇지 않을 경우보다 1.035배 증가한다.

# %%
sig_level = .05
logistic_variable = pd.concat([logreg.params, np.exp(logreg.params), np.round(logreg.pvalues,4)], axis=1)
logistic_variable.columns = ['logit', 'odds ratio', 'p-value']
logistic_variable.loc[logistic_variable['p-value'] > sig_level, f'above {sig_level*100}%'] = 'No'
logistic_variable.loc[logistic_variable['p-value'] < sig_level, f'above {sig_level*100}%'] = 'Yes'
print(logistic_variable)
# Out:
#                          logit  odds ratio  p-value above 5.0%
# const            -9.402936e-01    0.390513   0.0000        Yes
# MarketingType    -1.204735e+00    0.299771   0.0000        Yes
# ReleaseNumber     2.104675e-02    1.021270   0.0000        Yes
# New_Release_Flag -2.227898e-01    0.800283   0.0000        Yes
# StrengthFactor   -3.604660e-07    1.000000   0.0000        Yes
# PriceReg          6.818297e-04    1.000682   0.0004        Yes
# ItemCount         4.294967e-03    1.004304   0.0000        Yes
# LowUserPrice      3.344821e-04    1.000335   0.0023        Yes
# LowNetPrice      -5.505007e-03    0.994510   0.0000        Yes
# stockvalue        1.884232e-04    1.000188   0.0000        Yes
# stockage         -5.787898e-03    0.994229   0.0208        Yes
# discount          3.417032e-02    1.034761   0.1821         No

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm_df = pd.DataFrame(logreg.pred_table())
cm_df.columns = ['Predicted Active', 'Predicted Historical']
cm_df = cm_df.rename(index={0: 'Actual Active',1: 'Actual Historical'})
print(cm_df)

sns.heatmap(cm_df, cmap = 'RdYlBu_r', annot = True, annot_kws={"size": 10}, linewidths=.5, fmt='.0f')
plt.title('confusion matrix')
plt.xlabel('actual')
plt.ylabel('pred')
plt.show()
# Out:
#                    Predicted Active  Predicted Historical
# Actual Active               42663.0                 649.0
# Actual Historical            7983.0                 925.0

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion='gini', max_depth=7,
                               min_samples_leaf=2, min_samples_split=2,
                               max_features=12)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=12, min_samples_leaf=2)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8362208868810036
#
# confusion matrix:
# [[18563   362]
#  [ 3372   502]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.98      0.91     18925
#          1.0       0.58      0.13      0.21      3874
#
#     accuracy                           0.84     22799
#    macro avg       0.71      0.56      0.56     22799
# weighted avg       0.80      0.84      0.79     22799

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

model = SVC(kernel='linear', C= 1, gamma=1, class_weight=None, max_iter=100,
            random_state=1202)
model.fit(X_train, y_train)
# Out:
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC(C=1, gamma=1, kernel='linear', max_iter=100, random_state=1202)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.35071713671652266
#
# confusion matrix:
# [[ 4497 14428]
#  [  375  3499]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.24      0.38     18925
#          1.0       0.20      0.90      0.32      3874
#
#     accuracy                           0.35     22799
#    macro avg       0.56      0.57      0.35     22799
# weighted avg       0.80      0.35      0.37     22799

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.816132286503794
#
# confusion matrix:
# [[17713  1212]
#  [ 2980   894]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.94      0.89     18925
#          1.0       0.42      0.23      0.30      3874
#
#     accuracy                           0.82     22799
#    macro avg       0.64      0.58      0.60     22799
# weighted avg       0.78      0.82      0.79     22799

# %% [markdown]
# ## Hist Gradient Classifier

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

model = HistGradientBoostingClassifier(loss='log_loss', learning_rate=0.1, max_iter=1000, max_leaf_nodes=31, max_depth=7,
                                       min_samples_leaf=10)
model.fit(X_train, y_train)
# Out:
# HistGradientBoostingClassifier(max_depth=7, max_iter=1000, min_samples_leaf=10)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8376683187859116
#
# confusion matrix:
# [[18589   336]
#  [ 3365   509]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.98      0.91     18925
#          1.0       0.60      0.13      0.22      3874
#
#     accuracy                           0.84     22799
#    macro avg       0.72      0.56      0.56     22799
# weighted avg       0.81      0.84      0.79     22799

# %% [markdown]
# ## Stacking Classifier

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import LinearSVC
from sklearn.ensemble import StackingClassifier

estimators = [
    ('rf', RandomForestClassifier(n_estimators=300)),
    ('svr', make_pipeline(StandardScaler(),LinearSVC()))]

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.8366595026097636

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(n_estimators=500, algorithm="SAMME",learning_rate=1.3)
model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.3, n_estimators=500)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8372297030571516
#
# confusion matrix:
# [[18580   345]
#  [ 3366   508]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.98      0.91     18925
#          1.0       0.60      0.13      0.21      3874
#
#     accuracy                           0.84     22799
#    macro avg       0.72      0.56      0.56     22799
# weighted avg       0.80      0.84      0.79     22799

# %% [markdown]
# ## Ridge Classifier

# %%
from sklearn.linear_model import RidgeClassifierCV

model = RidgeClassifierCV(cv=10)
model.fit(X_train, y_train)
# Out:
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.81155e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.77906e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.82903e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.66188e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.78967e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.80304e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.80917e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.76243e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.67565e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.74703e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.81155e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.77906e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.82903e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.66188e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.78967e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.80304e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.80917e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.76243e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.67565e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.74703e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.81155e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.77906e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.82903e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.66188e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.78967e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.80304e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.80917e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.76243e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.67565e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.74703e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.88984e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# RidgeClassifierCV(cv=10)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8316592833018992
#
# confusion matrix:
# [[18795   130]
#  [ 3708   166]]
#
# report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.99      0.91     18925
#          1.0       0.56      0.04      0.08      3874
#
#     accuracy                           0.83     22799
#    macro avg       0.70      0.52      0.49     22799
# weighted avg       0.79      0.83      0.77     22799
