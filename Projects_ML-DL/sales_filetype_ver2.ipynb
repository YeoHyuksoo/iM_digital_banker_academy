# %%
import pandas as pd

df = pd.read_csv("SalesKaggle3.csv")
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198917 entries, 0 to 198916
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order             198917 non-null  int64
#  1   File_Type         198917 non-null  object
#  2   SKU_number        198917 non-null  int64
#  3   SoldFlag          75996 non-null   float64
#  4   SoldCount         75996 non-null   float64
#  5   MarketingType     198917 non-null  object
#  6   ReleaseNumber     198917 non-null  int64
#  7   New_Release_Flag  198917 non-null  int64
#  8   StrengthFactor    198917 non-null  float64
#  9   PriceReg          198917 non-null  float64
#  10  ReleaseYear       198917 non-null  int64
#  11  ItemCount         198917 non-null  int64
#  12  LowUserPrice      198917 non-null  float64
#  13  LowNetPrice       198917 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 21.2+ MB

# %%
df.isna().sum()
# Out:
# Order                    0
# File_Type                0
# SKU_number               0
# SoldFlag            122921
# SoldCount           122921
# MarketingType            0
# ReleaseNumber            0
# New_Release_Flag         0
# StrengthFactor           0
# PriceReg                 0
# ReleaseYear              0
# ItemCount                0
# LowUserPrice             0
# LowNetPrice              0
# dtype: int64

# %%
df.groupby(["File_Type"])['Order'].count()
# Out:
# File_Type
# Active        122921
# Historical     75996
# Name: Order, dtype: int64

# %%
df.groupby(["File_Type"])['SoldFlag'].count()
# Out:
# File_Type
# Active            0
# Historical    75996
# Name: SoldFlag, dtype: int64

# %%
df.groupby(["File_Type"])['SoldCount'].count()
# Out:
# File_Type
# Active            0
# Historical    75996
# Name: SoldCount, dtype: int64

# %%
zero = df[(df.PriceReg == 0) & (df.LowUserPrice == 0) & (df.LowNetPrice == 0)]
zero = zero.sort_values(by="SKU_number")
zero.head()
# Out:
#        Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 19046  19489  Historical      105850       0.0        0.0             D
# 20767  21246  Historical      110438       0.0        0.0             D
# 42484  48298  Historical      111348       0.0        0.0             S
# 20163  20633  Historical      190433       0.0        0.0             D
# 11303  11625  Historical      255394       0.0        0.0             D
#
#        ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 19046             16                 1       3288165.0       0.0         2005
# 20767              4                 1       2255889.0       0.0         2005
# 42484              6                 1        252051.0       0.0         2009
# 20163              5                 1       1520607.0       0.0         2001
# 11303              3                 1        605870.0       0.0         2002
#
#        ItemCount  LowUserPrice  LowNetPrice
# ...

# %%
zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 19046 to 76752
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order             117 non-null    int64
#  1   File_Type         117 non-null    object
#  2   SKU_number        117 non-null    int64
#  3   SoldFlag          38 non-null     float64
#  4   SoldCount         38 non-null     float64
#  5   MarketingType     117 non-null    object
#  6   ReleaseNumber     117 non-null    int64
#  7   New_Release_Flag  117 non-null    int64
#  8   StrengthFactor    117 non-null    float64
#  9   PriceReg          117 non-null    float64
#  10  ReleaseYear       117 non-null    int64
#  11  ItemCount         117 non-null    int64
#  12  LowUserPrice      117 non-null    float64
#  13  LowNetPrice       117 non-null    float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 13.7+ KB

# %%
zero.groupby(["File_Type"])['SKU_number'].count()
# Out:
# File_Type
# Active        79
# Historical    38
# Name: SKU_number, dtype: int64

# %%
drop = df.drop_duplicates(subset='SKU_number')
drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133360 entries, 0 to 198901
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order             133360 non-null  int64
#  1   File_Type         133360 non-null  object
#  2   SKU_number        133360 non-null  int64
#  3   SoldFlag          75996 non-null   float64
#  4   SoldCount         75996 non-null   float64
#  5   MarketingType     133360 non-null  object
#  6   ReleaseNumber     133360 non-null  int64
#  7   New_Release_Flag  133360 non-null  int64
#  8   StrengthFactor    133360 non-null  float64
#  9   PriceReg          133360 non-null  float64
#  10  ReleaseYear       133360 non-null  int64
#  11  ItemCount         133360 non-null  int64
#  12  LowUserPrice      133360 non-null  float64
#  13  LowNetPrice       133360 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 15.3+ MB

# %%
dup = df[df.duplicated(subset='SKU_number', keep=False)]
dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131114 entries, 3676 to 198916
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order             131114 non-null  int64
#  1   File_Type         131114 non-null  object
#  2   SKU_number        131114 non-null  int64
#  3   SoldFlag          65557 non-null   float64
#  4   SoldCount         65557 non-null   float64
#  5   MarketingType     131114 non-null  object
#  6   ReleaseNumber     131114 non-null  int64
#  7   New_Release_Flag  131114 non-null  int64
#  8   StrengthFactor    131114 non-null  float64
#  9   PriceReg          131114 non-null  float64
#  10  ReleaseYear       131114 non-null  int64
#  11  ItemCount         131114 non-null  int64
#  12  LowUserPrice      131114 non-null  float64
#  13  LowNetPrice       131114 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 15.0+ MB

# %%
dup = dup.sort_values(by = 'SKU_number')
dup.head(10)
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 154943  164054      Active       50001       NaN        NaN             S
# 57255    63770  Historical       50001       0.0        0.0             S
# 12935    13283  Historical       50002       0.0        0.0             D
# 154954  164065      Active       50002       NaN        NaN             D
# 154942  164053      Active       50003       NaN        NaN             D
# 12927    13275  Historical       50003       0.0        0.0             D
# 135184  144295      Active       50004       NaN        NaN             D
# 5328      5552  Historical       50004       0.0        0.0             D
# 135182  144293      Active       50005       NaN        NaN             D
# 5326      5550  Historical       50005       0.0        0.0             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 154943              8                 1    8.050918e+05    149.35
# ...

# %%
nodup = pd.merge(dup, df, how='outer', indicator=True).query('_merge == "right_only"').drop(columns=['_merge'])
nodup.head(10)
# Out:
#         Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 131114      2  Historical     1737127       0.0        0.0             D
# 131115      3  Historical     3255963       0.0        0.0             D
# 131116      4  Historical      612701       0.0        0.0             D
# 131117      6  Historical      115883       1.0        1.0             D
# 131118      7  Historical      863939       1.0        1.0             D
# 131119      8  Historical      214948       0.0        0.0             D
# 131120      9  Historical      484059       0.0        0.0             D
# 131121     10  Historical      146401       0.0        0.0             D
# 131122     11  Historical      110568       0.0        0.0             D
# 131123     12  Historical      764270       0.0        0.0             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 131114             15                 1        682743.0     44.99
# ...

# %%
nodup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67803 entries, 131114 to 198916
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order             67803 non-null  int64
#  1   File_Type         67803 non-null  object
#  2   SKU_number        67803 non-null  int64
#  3   SoldFlag          10439 non-null  float64
#  4   SoldCount         10439 non-null  float64
#  5   MarketingType     67803 non-null  object
#  6   ReleaseNumber     67803 non-null  int64
#  7   New_Release_Flag  67803 non-null  int64
#  8   StrengthFactor    67803 non-null  float64
#  9   PriceReg          67803 non-null  float64
#  10  ReleaseYear       67803 non-null  int64
#  11  ItemCount         67803 non-null  int64
#  12  LowUserPrice      67803 non-null  float64
#  13  LowNetPrice       67803 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 7.8+ MB

# %%
nodup.sort_values(by="SKU_number")
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 136246   38207  Historical       50011       0.0        0.0             S
# 144599   88153      Active       50027       NaN        NaN             D
# 131908     802  Historical       50032       0.0        0.0             D
# 144531   88085      Active       50042       NaN        NaN             D
# 136024   37939  Historical       50061       0.0        0.0             S
# ...        ...         ...         ...       ...        ...           ...
# 180878  124432      Active     3960560       NaN        NaN             S
# 175136  118690      Active     3960724       NaN        NaN             S
# 141606   85160      Active     3960742       NaN        NaN             S
# 193362  136916      Active     3960760       NaN        NaN             S
# 182141  125695      Active     3960788       NaN        NaN             S
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
nodup.groupby(["File_Type"])['ReleaseNumber'].count()
# Out:
# File_Type
# Active        57364
# Historical    10439
# Name: ReleaseNumber, dtype: int64

# %%
nodup = nodup.sort_values(by = 'SKU_number')
nodup.head(10)
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 136246   38207  Historical       50011       0.0        0.0             S
# 144599   88153      Active       50027       NaN        NaN             D
# 131908     802  Historical       50032       0.0        0.0             D
# 144531   88085      Active       50042       NaN        NaN             D
# 136024   37939  Historical       50061       0.0        0.0             S
# 135288   36761  Historical       50068       0.0        0.0             S
# 135353   36857  Historical       50113       0.0        0.0             S
# 172297  115851      Active       50126       NaN        NaN             S
# 136137   38062  Historical       50146       0.0        0.0             S
# 138334   42989  Historical       50154       0.0        0.0             S
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 136246              5                 1     1403114.000    223.80
# ...

# %%
nodup_hist = nodup[nodup.File_Type == 'Historical']
nodup_act = nodup[nodup.File_Type == 'Active']

# %%
nodup_hist.head(10)
# Out:
#         Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 136246  38207  Historical       50011       0.0        0.0             S
# 131908    802  Historical       50032       0.0        0.0             D
# 136024  37939  Historical       50061       0.0        0.0             S
# 135288  36761  Historical       50068       0.0        0.0             S
# 135353  36857  Historical       50113       0.0        0.0             S
# 136137  38062  Historical       50146       0.0        0.0             S
# 138334  42989  Historical       50154       0.0        0.0             S
# 135365  36870  Historical       50167       0.0        0.0             S
# 135876  37751  Historical       50171       0.0        0.0             S
# 131462    356  Historical       50186       0.0        0.0             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 136246              5                 1       1403114.0    223.80
# ...

# %%
nodup_act.head(10)
# Out:
#          Order File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 144599   88153    Active       50027       NaN        NaN             D
# 144531   88085    Active       50042       NaN        NaN             D
# 172297  115851    Active       50126       NaN        NaN             S
# 183096  126650    Active       50162       NaN        NaN             S
# 167561  111115    Active       50195       NaN        NaN             S
# 142284   85838    Active       50207       NaN        NaN             D
# 169146  112700    Active       50281       NaN        NaN             S
# 142148   85702    Active       50298       NaN        NaN             D
# 170180  113734    Active       50393       NaN        NaN             S
# 142902   86456    Active       50403       NaN        NaN             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 144599              3                 1    1.841125e+06     61.00
# ...

# %%
dup_hist = dup[dup.File_Type == 'Historical']
dup_act = dup[dup.File_Type == 'Active']

# %%
dup.groupby(["File_Type"])['New_Release_Flag'].sum()
# Out:
# File_Type
# Active        51389
# Historical    51562
# Name: New_Release_Flag, dtype: int64

# %%
dup_hist.head(10)
# Out:
#        Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 57255  63770  Historical       50001       0.0        0.0             S
# 12935  13283  Historical       50002       0.0        0.0             D
# 12927  13275  Historical       50003       0.0        0.0             D
# 5328    5552  Historical       50004       0.0        0.0             D
# 5326    5550  Historical       50005       0.0        0.0             D
# 5327    5551  Historical       50006       1.0        1.0             D
# 25657  26229  Historical       50009       0.0        0.0             D
# 25668  26240  Historical       50012       0.0        0.0             D
# 33186  33928  Historical       50013       0.0        0.0             D
# 33189  33931  Historical       50014       0.0        0.0             D
#
#        ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 57255              8                 1       2167227.0    149.35         2003
# ...

# %%
dup_act.head(10)
# Out:
#          Order File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 154943  164054    Active       50001       NaN        NaN             S
# 154954  164065    Active       50002       NaN        NaN             D
# 154942  164053    Active       50003       NaN        NaN             D
# 135184  144295    Active       50004       NaN        NaN             D
# 135182  144293    Active       50005       NaN        NaN             D
# 135183  144294    Active       50006       NaN        NaN             D
# 179302  188413    Active       50009       NaN        NaN             D
# 179320  188431    Active       50012       NaN        NaN             D
# 194910  204021    Active       50013       NaN        NaN             D
# 194913  204024    Active       50014       NaN        NaN             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 154943              8                 1    805091.78880    149.35
# ...

# %%
df.StrengthFactor.describe()
# Out:
# count    1.989170e+05
# mean     1.117115e+06
# std      1.522090e+06
# min      6.275000e+00
# 25%      1.614188e+05
# 50%      5.822240e+05
# 75%      1.430083e+06
# max      1.738445e+07
# Name: StrengthFactor, dtype: float64

# %%
q1=df['StrengthFactor'].quantile(0.25)
q2=df['StrengthFactor'].quantile(0.5)
q3=df['StrengthFactor'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 1268664.2325

# %%
condition=(df['StrengthFactor'] < q3+1.5*iqr) & (df['StrengthFactor'] > q1-1.5*iqr)
clean_df = df[condition]
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183862 entries, 0 to 198916
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order             183862 non-null  int64
#  1   File_Type         183862 non-null  object
#  2   SKU_number        183862 non-null  int64
#  3   SoldFlag          69741 non-null   float64
#  4   SoldCount         69741 non-null   float64
#  5   MarketingType     183862 non-null  object
#  6   ReleaseNumber     183862 non-null  int64
#  7   New_Release_Flag  183862 non-null  int64
#  8   StrengthFactor    183862 non-null  float64
#  9   PriceReg          183862 non-null  float64
#  10  ReleaseYear       183862 non-null  int64
#  11  ItemCount         183862 non-null  int64
#  12  LowUserPrice      183862 non-null  float64
#  13  LowNetPrice       183862 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 21.0+ MB

# %%
print(clean_df["SoldFlag"].value_counts() / len(clean_df["SoldFlag"]))
# Out:
# 0.0    0.310494
# 1.0    0.068818
# Name: SoldFlag, dtype: float64

# %%
print(clean_df["File_Type"].value_counts() / len(clean_df["File_Type"]))
# Out:
# Active        0.620688
# Historical    0.379312
# Name: File_Type, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for column in clean_df.select_dtypes(include=['object']).columns:
    clean_df[column] = le.fit_transform(clean_df[column])

clean_df.head()
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_34700\4017447135.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df[column] = le.fit_transform(clean_df[column])
# C:\Users\82102\AppData\Local\Temp\ipykernel_34700\4017447135.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df[column] = le.fit_transform(clean_df[column])
#    Order  File_Type  SKU_number  SoldFlag  SoldCount  MarketingType  \
# 0      2          1     1737127       0.0        0.0              0
# ...

# %%
X = clean_df.drop(columns=["File_Type","SoldFlag","SoldCount","Order","SKU_number"])
y = clean_df["SoldFlag"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3)

# %%
X.columns
# Out:
# Index(['MarketingType', 'ReleaseNumber', 'New_Release_Flag', 'StrengthFactor',
#        'PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice'],
#       dtype='object')

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (128703, 9)
# (55159, 9)
# (128703,)
# (55159,)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8916405301038816
#
# confusion matrix:
# [[32283  1855]
#  [ 4122 16899]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92     34138
#            1       0.90      0.80      0.85     21021
#
#     accuracy                           0.89     55159
#    macro avg       0.89      0.87      0.88     55159
# weighted avg       0.89      0.89      0.89     55159

# %%
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

print(feature_importance)
# Out:
#             feature  importance
# 7      LowUserPrice    0.539070
# 8       LowNetPrice    0.106281
# 3    StrengthFactor    0.084170
# 4          PriceReg    0.065825
# 6         ItemCount    0.063414
# 1     ReleaseNumber    0.053741
# 5       ReleaseYear    0.045943
# 0     MarketingType    0.028484
# 2  New_Release_Flag    0.013073

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=10)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8308344966369948
#
# confusion matrix:
# [[32253  1885]
#  [ 7446 13575]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87     34138
#            1       0.88      0.65      0.74     21021
#
#     accuracy                           0.83     55159
#    macro avg       0.85      0.80      0.81     55159
# weighted avg       0.84      0.83      0.82     55159

# %% [markdown]
# ## XGB classifier

# %%
from xgboost import XGBClassifier

model = XGBClassifier(n_estimators=300, subsample=0.9, max_depth=4, learning_rate=0.1, gamma=0.5,
                      colsample_bytree=1.0, importance_type='cover', reg_lambda = 1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type='cover',
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.9020468101307131
#
# confusion matrix:
# [[32312  1826]
#  [ 3577 17444]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92     34138
#            1       0.91      0.83      0.87     21021
#
#     accuracy                           0.90     55159
#    macro avg       0.90      0.89      0.89     55159
# weighted avg       0.90      0.90      0.90     55159

# %%
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

print(feature_importance)
# Out:
#             feature  importance
# 7      LowUserPrice    0.169466
# 5       ReleaseYear    0.169004
# 1     ReleaseNumber    0.132969
# 8       LowNetPrice    0.116499
# 3    StrengthFactor    0.109584
# 6         ItemCount    0.102730
# 0     MarketingType    0.100275
# 4          PriceReg    0.099473
# 2  New_Release_Flag    0.000000

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=100000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8065229608948675
#
# confusion matrix:
# [[31396  2742]
#  [ 7930 13091]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85     34138
#            1       0.83      0.62      0.71     21021
#
#     accuracy                           0.81     55159
#    macro avg       0.81      0.77      0.78     55159
# weighted avg       0.81      0.81      0.80     55159

# %% [markdown]
# ## Desicion Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion='gini', max_depth=7,
                               min_samples_leaf=2, min_samples_split=2,
                               max_features=12)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=12, min_samples_leaf=2)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.8746895338929277
#
# confusion matrix:
# [[32077  2061]
#  [ 4851 16170]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     34138
#            1       0.89      0.77      0.82     21021
#
#     accuracy                           0.87     55159
#    macro avg       0.88      0.85      0.86     55159
# weighted avg       0.88      0.87      0.87     55159

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

model = SVC(kernel='linear', C= 1, gamma=1, class_weight=None, max_iter=100,
            random_state=1202)
model.fit(X_train, y_train)
# Out:
# /Users/haegyul/PycharmProjects/Source/AI310_01/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC(C=1, gamma=1, kernel='linear', max_iter=100, random_state=1202)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.3818597146431226
#
# confusion matrix:
# [[   86 34052]
#  [   44 20977]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.00      0.01     34138
#            1       0.38      1.00      0.55     21021
#
#     accuracy                           0.38     55159
#    macro avg       0.52      0.50      0.28     55159
# weighted avg       0.55      0.38      0.21     55159

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
# Out:
# accuracy: 0.7737631211588317
#
# confusion matrix:
# [[32605  1533]
#  [10946 10075]]
#
# report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84     34138
#            1       0.87      0.48      0.62     21021
#
#     accuracy                           0.77     55159
#    macro avg       0.81      0.72      0.73     55159
# weighted avg       0.79      0.77      0.75     55159

# %% [markdown]
# ## Hist Gradient Classifier

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

model = HistGradientBoostingClassifier(loss='log_loss', learning_rate=0.1, max_iter=1000, max_leaf_nodes=31, max_depth=7,
                                       min_samples_leaf=10)
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)

# %% [markdown]
# ## Voting classifier

# %%
clf1 = RandomForestClassifier(n_estimators=3000, max_depth=12, min_samples_split=10, 
                               min_samples_leaf=10, class_weight=None, random_state=1)
clf2 = XGBClassifier(n_estimators=300, subsample=0.9, max_depth=4, learning_rate=0.1, gamma=0.5,
                      colsample_bytree=1.0, importance_type='cover', reg_lambda = 1, 
                      scale_pos_weight=1.3, random_state=1202)
clf3 = HistGradientBoostingClassifier(loss='log_loss', learning_rate=0.1, max_iter=1000, max_leaf_nodes=31, max_depth=7,
                                       min_samples_leaf=10)

# %%
from sklearn.ensemble import VotingClassifier

eclf = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('gnb', clf3)], voting='hard')

# %%
# from sklearn.model_selection import cross_val_score

# for clf, label in zip([clf1, clf2, clf3, eclf], ['Logistic Regression', 'Random Forest', 'naive Bayes', 'Ensemble']):
#     scores = cross_val_score(clf, X, y, scoring='accuracy', cv=5)
#     print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))

# %% [markdown]
# ## Stacking classifier

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import LinearSVC
from sklearn.ensemble import StackingClassifier

estimators = [
    ('rf', RandomForestClassifier(n_estimators=300)),
    ('svr', make_pipeline(StandardScaler(),LinearSVC()))]

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# %%
clf.fit(X_train, y_train).score(X_test, y_test)

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(n_estimators=500, algorithm="SAMME",learning_rate=1.3)
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)

# %% [markdown]
# ## Ridge Classifier

# %%
from sklearn.linear_model import RidgeClassifierCV

model = RidgeClassifierCV(cv=10)
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"accuracy: {accuracy}")
print("\nconfusion matrix:")
print(confusion)
print("\nreport:")
print(report)
